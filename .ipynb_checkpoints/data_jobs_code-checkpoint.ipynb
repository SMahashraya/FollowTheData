# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib
import re

# %%
# Read in data jobs csv files
al = pd.read_csv("Indeed_job_results_Analytics_2019-01-09.csv")
bi = pd.read_csv("Indeed_job_results_Business_Intelligence_Analyst_2019-01-09.csv")
da = pd.read_csv("Indeed_job_results_Data_Analyst_2019-01-09.csv")
de = pd.read_csv("Indeed_job_results_Data_Engineer_2019-01-09.csv")
ds = pd.read_csv("Indeed_job_results_Data_Scientist_2019-01-09.csv")
st = pd.read_csv("Indeed_job_results_Statistician_2019-01-09.csv")

# Concatenate data job files into a single dataframe
data_jobs = pd.concat([al, bi, da, de, ds, st])

# Create a column for job categories and iterate through dataset to categorize each job title

data_jobs["Job Category"] = ""
for i, row in data_jobs.iterrows():
    if re.search("Analytics", row["Title"].title()) or re.search("Analytic", row["Title"].title()):
        row["Job Category"] = "Analytics"
    elif re.search("Data", row["Title"].title()) and re.search("Analyst", row["Title"].title()):
        row["Job Category"] = "Data Analyst"
    elif re.search("Data", row["Title"].title()) and re.search("Scientist", row["Title"].title()):
        row["Job Category"] = "Data Scientist"
    elif re.search("Data", row["Title"].title()) and re.search("Engineer", row["Title"].title()):
        row["Job Category"] = "Data Engineer"
    elif re.search("Business", row["Title"].title()) and re.search("Intelligence", row["Title"].title()):   
        row["Job Category"] = "Business Intelligence Analyst"
    elif re.search("Intern", row["Title"].title()) or re.search("Internship", row["Title"].title()):
        row["Job Category"] = "Internship"
    elif re.search("Business", row["Title"].title()) and re.search("Analyst", row["Title"].title()):   
        row["Job Category"] = "Business Analyst"
    elif re.search("Developer", row["Title"].title()):   
        row["Job Category"] = "Developer"
    elif "Statistician" in row["Title"].title():
        row["Job Category"] = "Statistician"
    elif re.search("Manager", row["Title"].title()) or \
    re.search("Director", row["Title"].title()) or \
    re.search("Dir", row["Title"].title()) or \
    re.search("Lead", row["Title"].title()) or \
    re.search("Head", row["Title"].title()):
        row["Job Category"] = "Management"
    elif re.search("Research", row["Title"].title()):
        row["Job Category"] = "Research"
    else:
        row["Job Category"] = "Other"

# Pare dataframe down to relevant columns and rename columns

# Split Regions, MSAs, and Locations into cities
data_jobs["City"] = ""
data_jobs["State"] = ""
data_jobs["Location"].value_counts()
data_jobs[["City", "State"]] = data_jobs["Location"].str.split(",", n=1, expand=True)
data_jobs["State"] = data_jobs["State"].str.strip()
data_jobs[["State", "ZIP"]] = data_jobs["State"].str.split(" ", n=1, expand=True)
data_jobs["ZIP"] = data_jobs["ZIP"].str.strip()
data_jobs[["ZIP", "Area"]] = data_jobs["ZIP"].str.split(" ", n=1, expand=True)

# Finalize clean jobs dataframes
# data_jobs

# %%
# Read in rent csv file
rent = pd.read_csv("City_MedianRentalPrice_1Bedroom.csv")

# Pare the dataframe down to relevant columns and rename them if necessary
rent_columns = ["RegionName", "State", "Metro", "CountyName", "SizeRank", "2018-11"]
rent = rent[rent_columns]
rent.rename(columns = {"RegionName" : "City", "CountyName" : "County"}, inplace = True)

# Split Metro into city columns
rent["City1"] = ""
rent["City2"] = ""
rent["City3"] = ""
rent[["City1", "City2", "City3"]] = rent["Metro"].str.split("-", n=2, expand = True)

# Finalize clean rent file
# rent
# Out:
#                    City State                                       Metro  \
# 0              New York    NY                 New York-Newark-Jersey City
# 3        The Woodlands               Sugar Land
# 4        New Braunfels                     None
# 5               Camden               Wilmington
# 6                 Mesa               Scottsdale
# 7            Henderson                 Paradise
# 8             Carlsbad                     None
# 9           Fort Worth                Arlington
# 10           Sunnyvale              Santa Clara
# 11          Round Rock                     None
# 12                None                     None
# 13             Oakland                  Hayward
# 14              Carmel                 Anderson
# 15             Concord                 Gastonia
# 16          Fort Worth                Arlington
# 17                None                     None
# 18                None                     None
# 19                None                     None
# 20                None                     None
# 21           Kissimmee                  Sanford
# 22              Aurora                 Lakewood
# 23              Tacoma                 Bellevue
# 24                None                     None
# 25           Cambridge                   Newton
# 26           Arlington               Alexandria
# 27            Davidson  -Murfreesboro--Franklin
# 28           Vancouver                Hillsboro
# 29                      Roseville--Arden-Arcade
# ..                 ...                      ...
# 619           Columbia                   Towson
# 620        Schenectady                     Troy
# 621         Fort Worth                Arlington
# 622          Kissimmee                  Sanford
# 623             Aurora                 Lakewood
# 624  Fort Walton Beach                   Destin
# 625         Fort Worth                Arlington
# 626         Naperville                    Elgin
# 627             Newark              Jersey City
# 628      Sandy Springs                  Roswell
# 629             Aurora                 Lakewood
# 630         Naperville                    Elgin
# 631    Fort Lauderdale          West Palm Beach
# 632             Newark              Jersey City
# 633             Newark              Jersey City
# 634             Newark              Jersey City
# 635             Camden               Wilmington
# 636               None                     None
# 637          Arlington               Alexandria
# 638            Oakland                  Hayward
# 639          Arlington               Alexandria
# 640         Long Beach                  Anaheim
# 641               None                     None
# 642      Sandy Springs                  Roswell
# 643          Arlington               Alexandria
# 644    Fort Lauderdale          West Palm Beach
# 645    Fort Lauderdale          West Palm Beach
# 646    Fort Lauderdale          West Palm Beach
# 647    Fort Lauderdale          West Palm Beach
# 648    Fort Lauderdale          West Palm Beach
#
# [649 rows x 9 columns]

# %%
# Read in salary csv file
salary = pd.read_csv("MSA_M2017_dl.csv")

# Pare the dataframe down to relevant columns and rename them if necessary
salary_columns = ["PRIM_STATE", "AREA_NAME", "OCC_TITLE", "TOT_EMP", "EMP_PRSE", "JOBS_1000", "H_MEDIAN", "A_MEDIAN"]
salary = salary[salary_columns]
salary.rename(columns = {"PRIM_STATE" : "State", 
                         "AREA_NAME" : "Area", 
                         "OCC_TITLE" : "Occupation", 
                         "TOT_EMP" : "Estimated Total Employment", 
                         "EMP_PRSE" : "Employment Percent RSE",
                         "JOBS_1000" : "Occupation per 1000", 
                         "H_MEDIAN" : "Hourly Median Wage", 
                         "A_MEDIAN" : "Annual Median Salary"}, inplace = True)
salary = salary.loc[salary["Occupation"] == "All Occupations"]
salary["City1"] = ""
salary["State2"] = ""
salary[["City1", "State2"]] = salary["Area"].str.split(",", expand = True)
salary["City1"] = salary["City1"].str.strip()
salary
# salary[["City2", "City3"]] = salary["City1"].str.split("-")
# salary[["City1", "City2", "City3"]]
# Out:
#        State                                               Area  \
# 0         AK                                      Anchorage, AK
# 463       AK                                      Fairbanks, AK
# 685       AL                   Anniston-Oxford-Jacksonville, AL
# 904       AL                                 Auburn-Opelika, AL
# 1123      AL                              Birmingham-Hoover, AL
# 1671      AL                          Daphne-Fairhope-Foley, AL
# 1938      AL                                        Decatur, AL
# 2173      AL                                         Dothan, AL
# 2411      AL                         Florence-Muscle Shoals, AL
# 2651      AL                                        Gadsden, AL
# 2817      AL                                     Huntsville, AL
# 3237      AL                                         Mobile, AL
# 3647      AL                                     Montgomery, AL
# 4057      AL                                     Tuscaloosa, AL
# 4393      AR              Fayetteville-Springdale-Rogers, AR-MO
# 4840      AR                                  Fort Smith, AR-OK
# 5188      AR                                    Hot Springs, AR
# 5381      AR                                      Jonesboro, AR
# 5639      AR           Little Rock-North Little Rock-Conway, AR
# 6166      AR                                     Pine Bluff, AR
# 6328      AZ                                      Flagstaff, AZ
# 6603      AZ                       Lake Havasu City-Kingman, AZ
# 6843      AZ                        Phoenix-Mesa-Scottsdale, AZ
# 7528      AZ                                       Prescott, AZ
# 7821      AZ                           Sierra Vista-Douglas, AZ
# 8035      AZ                                         Tucson, AZ
# 8556      AZ                                           Yuma, AZ
# 8813      CA  Anaheim-Santa Ana-Irvine, CA Metropolitan Divi...
# 9462      CA                                    Bakersfield, CA
# 9944      CA                                          Chico, CA
# ...      ...                                                ...
# 146725    WA                                       Longview, WA
# 146926    WA                         Mount Vernon-Anacortes, WA
# 147183    WA                               Olympia-Tumwater, WA
# 147528    WA  Seattle-Bellevue-Everett, WA Metropolitan Divi...
# 148233    WA                         Spokane-Spokane Valley, WA
# 148716    WA          Tacoma-Lakewood, WA Metropolitan Division
# 149206    WA                                    Walla Walla, WA
# 149382    WA                                      Wenatchee, WA
# 149612    WA                                         Yakima, WA
# 149934    WI                                       Appleton, WI
# 150303    WI                                     Eau Claire, WI
# 150628    WI                                    Fond du Lac, WI
# 150860    WI                                      Green Bay, WI
# 151291    WI                              Janesville-Beloit, WI
# 151581    WI                          La Crosse-Onalaska, WI-MN
# 151876    WI                                        Madison, WI
# 152428    WI                  Milwaukee-Waukesha-West Allis, WI
# 153050    WI                                 Oshkosh-Neenah, WI
# 153372    WI                                         Racine, WI
# 153647    WI                                      Sheboygan, WI
# 153905    WI                                         Wausau, WI
# 154194    WV                                        Beckley, WV
# 154400    WV                                     Charleston, WV
# 154771    WV                       Huntington-Ashland, WV-KY-OH
# 155166    WV                                     Morgantown, WV
# 155434    WV                             Parkersburg-Vienna, WV
# 155624    WV                        Weirton-Steubenville, WV-OH
# 155837    WV                                    Wheeling, WV-OH
# 156122    WY                                         Casper, WY
# 156334    WY                                       Cheyenne, WY
#
#              Occupation Estimated Total Employment Employment Percent RSE  \
# 0       All Occupations                    173,420                    1.3
# 463     All Occupations                     36,650                    2.7
# 685     All Occupations                     43,110                    2.2
# 904     All Occupations                     56,410                    1.8
# 1123    All Occupations                    504,290                    0.6
# 1671    All Occupations                     71,190                    1.8
# 1938    All Occupations                     52,310                    2.0
# 2173    All Occupations                     56,400                    1.4
# 2411    All Occupations                     53,450                    2.9
# 2651    All Occupations                     35,630                    3.6
# 2817    All Occupations                    222,080                    1.3
# 3237    All Occupations                    172,750                    1.3
# 3647    All Occupations                    164,610                    1.8
# 4057    All Occupations                    100,100                    1.7
# 4393    All Occupations                    239,920                    2.5
# 4840    All Occupations                    107,840                    2.7
# 5188    All Occupations                     35,400                    3.4
# 5381    All Occupations                     54,890                    3.1
# 5639    All Occupations                    347,590                    1.1
# 6166    All Occupations                     30,960                    2.3
# 6328    All Occupations                     60,810                    4.6
# 6603    All Occupations                     47,430                    2.2
# 6843    All Occupations                  1,980,010                    0.6
# 7528    All Occupations                     61,560                    3.4
# 7821    All Occupations                     32,000                    2.6
# 8035    All Occupations                    364,930                    1.4
# 8556    All Occupations                     60,430                    3.2
# 8813    All Occupations                  1,616,210                    0.4
# 9462    All Occupations                    303,620                    1.0
# 9944    All Occupations                     80,110                    4.8
# ...                 ...                        ...                    ...
# 146725  All Occupations                     37,100                    4.7
# 146926  All Occupations                     46,650                    2.5
# 147183  All Occupations                    109,400                    2.7
# 147528  All Occupations                  1,647,350                    1.3
# 148233  All Occupations                    232,920                    2.4
# 148716  All Occupations                    296,810                    1.1
# 149206  All Occupations                     25,260                    5.2
# 149382  All Occupations                     45,710                    2.7
# 149612  All Occupations                     89,640                    2.7
# 149934  All Occupations                    123,460                    2.2
# 150303  All Occupations                     81,980                    2.6
# 150628  All Occupations                     45,600                    5.9
# 150860  All Occupations                    173,030                    2.3
# 151291  All Occupations                     64,560                    2.8
# 151581  All Occupations                     73,800                    2.0
# 151876  All Occupations                    387,300                    2.3
# 152428  All Occupations                    841,550                    0.6
# 153050  All Occupations                     95,240                    2.6
# 153372  All Occupations                     74,850                    2.2
# 153647  All Occupations                     57,980                    3.5
# 153905  All Occupations                     70,020                    4.1
# 154194  All Occupations                     42,670                    2.8
# 154400  All Occupations                    111,090                    1.6
# 154771  All Occupations                    130,770                    3.0
# 155166  All Occupations                     64,520                    1.7
# 155434  All Occupations                     37,160                    4.1
# 155624  All Occupations                     37,250                    4.6
# 155837  All Occupations                     61,310                    2.9
# 156122  All Occupations                     37,590                    1.3
# 156334  All Occupations                     45,310                    1.4
#
#        Occupation per 1000 Hourly Median Wage Annual Median Salary  \
# 0                 1000.000              22.76               47,340
# 463               1000.000              23.15               48,150
# 685               1000.000              14.79               30,760
# 904               1000.000              14.13               29,400
# 1123              1000.000              17.41               36,220
# 1671              1000.000              13.57               28,230
# 1938              1000.000              15.09               31,380
# 2173              1000.000              14.10               29,320
# 2411              1000.000              14.36               29,870
# 2651              1000.000              12.87               26,760
# 2817              1000.000              18.62               38,720
# 3237              1000.000              16.67               34,680
# 3647              1000.000              15.66               32,560
# 4057              1000.000              15.74               32,740
# 4393              1000.000              16.11               33,510
# 4840              1000.000              13.64               28,360
# 5188              1000.000              12.94               26,910
# 5381              1000.000              13.88               28,870
# 5639              1000.000              16.38               34,070
# 6166              1000.000              14.87               30,920
# 6328              1000.000              15.61               32,470
# 6603              1000.000              14.40               29,950
# 6843              1000.000              17.92               37,280
# 7528              1000.000              15.63               32,500
# 7821              1000.000              17.56               36,520
# 8035              1000.000              16.66               34,650
# 8556              1000.000              13.79               28,690
# 8813              1000.000              19.39               40,340
# 9462              1000.000              16.32               33,940
# 9944              1000.000              16.36               34,020
# ...                    ...                ...                  ...
# 146725            1000.000              18.70               38,890
# 146926            1000.000              18.90               39,310
# 147183            1000.000              20.74               43,140
# 147528            1000.000              24.30               50,550
# 148233            1000.000              18.03               37,500
# 148716            1000.000              19.79               41,150
# 149206            1000.000              18.65               38,780
# 149382            1000.000              16.77               34,890
# 149612            1000.000              16.75               34,850
# 149934            1000.000              17.86               37,160
# 150303            1000.000              16.64               34,610
# 150628            1000.000              18.32               38,110
# 150860            1000.000              17.66               36,740
# 151291            1000.000              16.98               35,310
# 151581            1000.000              17.05               35,460
# 151876            1000.000              20.03               41,670
# 152428            1000.000              18.59               38,670
# 153050            1000.000              18.33               38,140
# 153372            1000.000              16.67               34,670
# 153647            1000.000              18.53               38,550
# 153905            1000.000              17.54               36,480
# 154194            1000.000              14.02               29,150
# 154400            1000.000              16.29               33,880
# 154771            1000.000              15.26               31,740
# 155166            1000.000              17.54               36,490
# 155434            1000.000              14.30               29,750
# 155624            1000.000              14.32               29,780
# 155837            1000.000              14.73               30,640
# 156122            1000.000              18.93               39,380
# 156334            1000.000              18.46               38,390
#
#                                        City1                     State2
# 0                                  Anchorage                         AK
# 463                                Fairbanks                         AK
# 685             Anniston-Oxford-Jacksonville                         AL
# 904                           Auburn-Opelika                         AL
# 1123                       Birmingham-Hoover                         AL
# 1671                   Daphne-Fairhope-Foley                         AL
# 1938                                 Decatur                         AL
# 2173                                  Dothan                         AL
# 2411                  Florence-Muscle Shoals                         AL
# 2651                                 Gadsden                         AL
# 2817                              Huntsville                         AL
# 3237                                  Mobile                         AL
# 3647                              Montgomery                         AL
# 4057                              Tuscaloosa                         AL
# 4393          Fayetteville-Springdale-Rogers                      AR-MO
# 4840                              Fort Smith                      AR-OK
# 5188                             Hot Springs                         AR
# 5381                               Jonesboro                         AR
# 5639    Little Rock-North Little Rock-Conway                         AR
# 6166                              Pine Bluff                         AR
# 6328                               Flagstaff                         AZ
# 6603                Lake Havasu City-Kingman                         AZ
# 6843                 Phoenix-Mesa-Scottsdale                         AZ
# 7528                                Prescott                         AZ
# 7821                    Sierra Vista-Douglas                         AZ
# 8035                                  Tucson                         AZ
# 8556                                    Yuma                         AZ
# 8813                Anaheim-Santa Ana-Irvine   CA Metropolitan Division
# 9462                             Bakersfield                         CA
# 9944                                   Chico                         CA
# ...                                      ...                        ...
# 146725                              Longview                         WA
# 146926                Mount Vernon-Anacortes                         WA
# 147183                      Olympia-Tumwater                         WA
# 147528              Seattle-Bellevue-Everett   WA Metropolitan Division
# 148233                Spokane-Spokane Valley                         WA
# 148716                       Tacoma-Lakewood   WA Metropolitan Division
# 149206                           Walla Walla                         WA
# 149382                             Wenatchee                         WA
# 149612                                Yakima                         WA
# 149934                              Appleton                         WI
# 150303                            Eau Claire                         WI
# 150628                           Fond du Lac                         WI
# 150860                             Green Bay                         WI
# 151291                     Janesville-Beloit                         WI
# 151581                    La Crosse-Onalaska                      WI-MN
# 151876                               Madison                         WI
# 152428         Milwaukee-Waukesha-West Allis                         WI
# 153050                        Oshkosh-Neenah                         WI
# 153372                                Racine                         WI
# 153647                             Sheboygan                         WI
# 153905                                Wausau                         WI
# 154194                               Beckley                         WV
# 154400                            Charleston                         WV
# 154771                    Huntington-Ashland                   WV-KY-OH
# 155166                            Morgantown                         WV
# 155434                    Parkersburg-Vienna                         WV
# 155624                  Weirton-Steubenville                      WV-OH
# 155837                              Wheeling                      WV-OH
# 156122                                Casper                         WY
# 156334                              Cheyenne                         WY
#
# [422 rows x 10 columns]

# %%
# Read in crime csv file
